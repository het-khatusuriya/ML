# %% [markdown]
# <a href="https://colab.research.google.com/github/het-khatusuriya/ML/blob/main/Pandas_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/nyc_weather.csv')# df= dataframe

# %% [markdown]
# # New section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#df is an variable we created that contains references of all the data available in excel file
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           37        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df['Sea Level PressureIn'][0:10:1] # slice -> substring(start,stop,step)

#A slice object is used to specify how to slice a sequence. You can specify where to start the slicing, and where to end. You can also specify the step,
#which allows you to e.g. slice only every other item.
# Out:
# 0    30.03
# 1    30.02
# 2    29.86
# 3    30.05
# 4    30.57
# 5    30.50
# 6    30.28
# 7    30.20
# 8    30.16
# 9    29.59
# Name: Sea Level PressureIn, dtype: float64

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['Sea Level PressureIn'][df['Events']=='Rain']
# Out:
# 8     30.16
# 9     29.59
# 15    29.52
# 26    30.03
# Name: Sea Level PressureIn, dtype: float64

# %%
df['Sea Level PressureIn'][df['Events'].isnull()]

#is_null function is used to return null values
# df['Events'].isnull()
# Out:
# 0     30.03
# 1     30.02
# 2     29.86
# 3     30.05
# 4     30.57
# 5     30.50
# 6     30.28
# 7     30.20
# 10    29.92
# 11    29.85
# 12    29.94
# 13    29.95
# 14    29.82
# 18    30.03
# 19    30.13
# 20    30.15
# 24    30.25
# 25    30.03
# 27    29.90
# 28    29.58
# 29    30.01
# 30    29.90
# Name: Sea Level PressureIn, dtype: float64

# %%
new_df=df.fillna(0,inplace=False)

#if inplace = true then it will be affect directly on main excel sheet, new_df is temporary variable

# %%
new_df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           37        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           37        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df.head(30)[5:20]

#head functions indicates top (n), top n numbers of lines and in parameters [n1:n2] where n1 is starting point and n2 indicates as Ending point
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# 12   1/13/2016           26         4        42                 29.94
# 13   1/14/2016           30        12        47                 29.95
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 16   1/17/2016           36        23        66                 29.78
# ...

# %%
df.tail(20)
#tail function Prints last values
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 11  01-12-2016           35        15        53                 29.85
# 12   1/13/2016           26         4        42                 29.94
# 13   1/14/2016           30        12        47                 29.95
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 16   1/17/2016           36        23        66                 29.78
# 17   1/18/2016           25         6        53                 29.83
# 18   1/19/2016           22         3        42                 30.03
# 19   1/20/2016           32        15        49                 30.13
# 20   1/21/2016           31        11        45                 30.15
# 21   1/22/2016           26         6        41                 30.21
# 22   1/23/2016           26        21        78                 29.77
# ...
